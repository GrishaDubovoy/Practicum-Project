# %% [markdown]
# <h1>Оглавление<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Прогнозирование-оттока-клентов-оператора-связи-&quot;Ниединогоразрыва.ком&quot;" data-toc-modified-id="Прогнозирование-оттока-клентов-оператора-связи-&quot;Ниединогоразрыва.ком&quot;-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Прогнозирование оттока клентов оператора связи "Ниединогоразрыва.ком"</a></span><ul class="toc-item"><li><span><a href="#Описание-задачи" data-toc-modified-id="Описание-задачи-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Описание задачи</a></span><ul class="toc-item"><li><span><a href="#Описание-услуг" data-toc-modified-id="Описание-услуг-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Описание услуг</a></span></li><li><span><a href="#Описание-данных" data-toc-modified-id="Описание-данных-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Описание данных</a></span></li></ul></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Импорт-необходимых-библиотек" data-toc-modified-id="Импорт-необходимых-библиотек-1.2.1"><span class="toc-item-num">1.2.1&nbsp;&nbsp;</span>Импорт необходимых библиотек</a></span></li><li><span><a href="#Чтение-данных" data-toc-modified-id="Чтение-данных-1.2.2"><span class="toc-item-num">1.2.2&nbsp;&nbsp;</span>Чтение данных</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-1.2.3"><span class="toc-item-num">1.2.3&nbsp;&nbsp;</span>Предобработка данных</a></span></li><li><span><a href="#Анализ-данных" data-toc-modified-id="Анализ-данных-1.2.4"><span class="toc-item-num">1.2.4&nbsp;&nbsp;</span>Анализ данных</a></span></li></ul></li><li><span><a href="#Подготовка-данных-для-модели-машинного-обучения" data-toc-modified-id="Подготовка-данных-для-модели-машинного-обучения-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Подготовка данных для модели машинного обучения</a></span><ul class="toc-item"><li><span><a href="#Добавим-target" data-toc-modified-id="Добавим-target-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Добавим target</a></span></li><li><span><a href="#Добавим-признак-&quot;время-жизни&quot;-клиента" data-toc-modified-id="Добавим-признак-&quot;время-жизни&quot;-клиента-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Добавим признак "время жизни" клиента</a></span></li><li><span><a href="#Обработаем-бинарные-и-категориальные-признаки" data-toc-modified-id="Обработаем-бинарные-и-категориальные-признаки-1.3.3"><span class="toc-item-num">1.3.3&nbsp;&nbsp;</span>Обработаем бинарные и категориальные признаки</a></span></li><li><span><a href="#Удалим-лишние-признаки-для-избежания-утечки-и-проверим-корреляцию" data-toc-modified-id="Удалим-лишние-признаки-для-избежания-утечки-и-проверим-корреляцию-1.3.4"><span class="toc-item-num">1.3.4&nbsp;&nbsp;</span>Удалим лишние признаки для избежания утечки и проверим корреляцию</a></span></li><li><span><a href="#Выделение-тестовой-выборки" data-toc-modified-id="Выделение-тестовой-выборки-1.3.5"><span class="toc-item-num">1.3.5&nbsp;&nbsp;</span>Выделение тестовой выборки</a></span></li></ul></li><li><span><a href="#Обучение-моделей" data-toc-modified-id="Обучение-моделей-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>Обучение моделей</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-1.4.1"><span class="toc-item-num">1.4.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-1.4.2"><span class="toc-item-num">1.4.2&nbsp;&nbsp;</span>Случайный лес</a></span></li><li><span><a href="#Градиентный-бустинг-LightGBM" data-toc-modified-id="Градиентный-бустинг-LightGBM-1.4.3"><span class="toc-item-num">1.4.3&nbsp;&nbsp;</span>Градиентный бустинг LightGBM</a></span></li><li><span><a href="#Градиентный-бустинг-CatBoost" data-toc-modified-id="Градиентный-бустинг-CatBoost-1.4.4"><span class="toc-item-num">1.4.4&nbsp;&nbsp;</span>Градиентный бустинг CatBoost</a></span></li></ul></li><li><span><a href="#Проверка-модели-на-тестовой-выборке" data-toc-modified-id="Проверка-модели-на-тестовой-выборке-1.5"><span class="toc-item-num">1.5&nbsp;&nbsp;</span>Проверка модели на тестовой выборке</a></span></li><li><span><a href="#Интерпретация-модели" data-toc-modified-id="Интерпретация-модели-1.6"><span class="toc-item-num">1.6&nbsp;&nbsp;</span>Интерпретация модели</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-1.7"><span class="toc-item-num">1.7&nbsp;&nbsp;</span>Вывод</a></span></li><li><span><a href="#План" data-toc-modified-id="План-1.8"><span class="toc-item-num">1.8&nbsp;&nbsp;</span>План</a></span></li><li><span><a href="#Вопросы:" data-toc-modified-id="Вопросы:-1.9"><span class="toc-item-num">1.9&nbsp;&nbsp;</span>Вопросы:</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Прогнозирование оттока клентов оператора связи "Ниединогоразрыва.ком"

# %% [markdown]
# ## Описание задачи
#
# Оператор связи «Ниединогоразрыва.ком» хочет научиться прогнозировать отток клиентов. Если выяснится, что пользователь планирует уйти, ему будут предложены промокоды и специальные условия. Команда оператора собрала персональные данные о некоторых клиентах, информацию об их тарифах и договорах.
#
# ### Описание услуг
#
# Оператор предоставляет два основных типа услуг:
#
# 1. Стационарную телефонную связь. Возможно подключение телефонного аппарата к нескольким линиям одновременно.
# 2. Интернет. Подключение может быть двух типов: через телефонную линию (DSL*,* от англ. *digital subscriber line*, «цифровая абонентская линия») или оптоволоконный кабель (*Fiber optic*).
#
# Также доступны такие услуги:
#
# - Интернет-безопасность: антивирус (*DeviceProtection*) и блокировка небезопасных сайтов (*OnlineSecurity*);
# - Выделенная линия технической поддержки (*TechSupport*);
# - Облачное хранилище файлов для резервного копирования данных (*OnlineBackup*);
# - Стриминговое телевидение (*StreamingTV*) и каталог фильмов (*StreamingMovies*).
#
# За услуги клиенты могут платить каждый месяц или заключить договор на 1–2 года. Доступны различные способы расчёта и возможность получения электронного чека.
#
# ### Описание данных
#
# Данные состоят из файлов, полученных из разных источников:
#
# - `contract.csv` — информация о договоре;
# - `personal.csv` — персональные данные клиента;
# - `internet.csv` — информация об интернет-услугах;
# - `phone.csv` — информация об услугах телефонии.
#
# Во всех файлах столбец `customerID` содержит код клиента.
#
# Информация о договорах актуальна на 1 февраля 2020.

# %% [markdown]
# ## Подготовка данных
#
# ### Импорт необходимых библиотек

# %%
#!pip install LightGBM

# %%
#!pip install Catboost

# %%
#!pip install phik

# %%
import pandas as pd
import numpy as np
import seaborn as sns

from random import randint
from matplotlib import pyplot as plt
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn.linear_model import LogisticRegression, LogisticRegressionCV
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import GridSearchCV, cross_val_score
from sklearn.metrics import roc_curve, roc_auc_score, accuracy_score
from phik import phik_matrix

import warnings

warnings.simplefilter('ignore')
warnings.filterwarnings('ignore')


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# ### Чтение данных

# %%
try:
    contract = pd.read_csv('final_provider/contract.csv')    
    personal = pd.read_csv('final_provider/personal.csv')
    internet = pd.read_csv('final_provider/internet.csv')  
    phone = pd.read_csv('final_provider/phone.csv') 
except FileNotFoundError:
    contract = pd.read_csv('/datasets/final_provider/contract.csv')  
    personal = pd.read_csv('/datasets/final_provider/personal.csv') 
    internet = pd.read_csv('/datasets/final_provider/internet.csv')  
    phone = pd.read_csv('/datasets/final_provider/phone.csv')

# %%
def first_look(data):
    display(data.head(5))
    display(data.info())

# %%
first_look(contract)
# Out:
#    customerID   BeginDate              EndDate            Type  \
# 0  7590-VHVEG  2020-01-01                   No  Month-to-month
# 1  5575-GNVDE  2017-04-01                   No        One year
# 2  3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month
# 3  7795-CFOCW  2016-05-01                   No        One year
# 4  9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month
#
#   PaperlessBilling              PaymentMethod  MonthlyCharges TotalCharges
# 0              Yes           Electronic check           29.85        29.85
# 1               No               Mailed check           56.95       1889.5
# 2              Yes               Mailed check           53.85       108.15
# 3               No  Bank transfer (automatic)           42.30      1840.75
# 4              Yes           Electronic check           70.70       151.65
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
# ...

# %%
print('Количество уникальных значений в стоолбце customerID -', contract['customerID'].nunique())
# Out:
# Количество уникальных значений в стоолбце customerID - 7043

# %% [markdown]
# Все ID пользователей уникальны, этот столбец будет использовать для индексации при объединении

# %%
first_look(personal)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents
# 0  7590-VHVEG  Female              0     Yes         No
# 1  5575-GNVDE    Male              0      No         No
# 2  3668-QPYBK    Male              0      No         No
# 3  7795-CFOCW    Male              0      No         No
# 4  9237-HQITU  Female              0      No         No
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     7043 non-null   object
#  1   gender         7043 non-null   object
#  2   SeniorCitizen  7043 non-null   int64
#  3   Partner        7043 non-null   object
#  4   Dependents     7043 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 275.2+ KB
# None

# %%
first_look(internet)
# Out:
#    customerID InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 0  7590-VHVEG             DSL             No          Yes               No
# 1  5575-GNVDE             DSL            Yes           No              Yes
# 2  3668-QPYBK             DSL            Yes          Yes               No
# 3  7795-CFOCW             DSL            Yes           No              Yes
# 4  9237-HQITU     Fiber optic             No           No               No
#
#   TechSupport StreamingTV StreamingMovies
# 0          No          No              No
# 1          No          No              No
# 2          No          No              No
# 3         Yes          No              No
# 4          No          No              No
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5517 entries, 0 to 5516
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        5517 non-null   object
# ...

# %%
first_look(phone)
# Out:
#    customerID MultipleLines
# 0  5575-GNVDE            No
# 1  3668-QPYBK            No
# 2  9237-HQITU            No
# 3  9305-CDSKC           Yes
# 4  1452-KIOVK           Yes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6361 entries, 0 to 6360
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   customerID     6361 non-null   object
#  1   MultipleLines  6361 non-null   object
# dtypes: object(2)
# memory usage: 99.5+ KB
# None

# %% [markdown]
# Несколько первых выводов о данных:
#
# *  Пропусков и значений NULL в данных нет
# *  Имена столбцов не соответствуют змеиному стилю
# *  В таблице `contract` данные у столбцов с датой необходимо привести к типу DiteTime
# *  В таблице `contract` тип данных у столбца `TotalCharges` необходимо привести к типу float
# *  Множество бинарных данных типа yes/no нужно будет преобразовать в 0/1 или булев тип True/False
# * Категориальные признаки закодируем используя OHE
# *  Для удобства работы объединим все данные в один дата фрэйм по `customerID`, пропуски будут из-за того что не все клиенты пользуются сразу и услугами интернета и телефона. Пропуски заполним значениями "No"

# %% [markdown]
# ### Предобработка данных
#
# Объединим две таблицы `contract` и `personal` в них количество записей одинаково, пропусков быть не должно

# %%
df = contract.set_index('customerID').join(personal.set_index('customerID'))

# %%
df.isna().sum()
# Out:
# BeginDate           0
# EndDate             0
# Type                0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# dtype: int64

# %%
df.head(5)
# Out:
#              BeginDate              EndDate            Type PaperlessBilling  \
# customerID
# 7590-VHVEG  2020-01-01                   No  Month-to-month              Yes
# 5575-GNVDE  2017-04-01                   No        One year               No
# 3668-QPYBK  2019-10-01  2019-12-01 00:00:00  Month-to-month              Yes
# 7795-CFOCW  2016-05-01                   No        One year               No
# 9237-HQITU  2019-09-01  2019-11-01 00:00:00  Month-to-month              Yes
#
#                         PaymentMethod  MonthlyCharges TotalCharges  gender  \
# customerID
# 7590-VHVEG           Electronic check           29.85        29.85  Female
# 5575-GNVDE               Mailed check           56.95       1889.5    Male
# 3668-QPYBK               Mailed check           53.85       108.15    Male
# 7795-CFOCW  Bank transfer (automatic)           42.30      1840.75    Male
# 9237-HQITU           Electronic check           70.70       151.65  Female
#
# ...

# %% [markdown]
# Пропусков нет, двигаемся дальше

# %% [markdown]
# Добавим к нашей общей таблице данные из таблицы `Phone`

# %%
df = df.join(phone.set_index('customerID'))

# %%
df.isna().sum()
# Out:
# BeginDate             0
# EndDate               0
# Type                  0
# PaperlessBilling      0
# PaymentMethod         0
# MonthlyCharges        0
# TotalCharges          0
# gender                0
# SeniorCitizen         0
# Partner               0
# Dependents            0
# MultipleLines       682
# dtype: int64

# %% [markdown]
# 682 клиента пользуются только интернетом и непользуются телефонной связью, по крайней мере у данного оператора. Пропуски заменим значениями `No`

# %%
df = df.fillna('No')

# %%
df.isna().sum()
# Out:
# BeginDate           0
# EndDate             0
# Type                0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# MultipleLines       0
# dtype: int64

# %% [markdown]
# Добавим к нашей общей таблице данные из таблицы `Internet`

# %%
df = df.join(internet.set_index('customerID'))

# %%
df.isna().sum()
# Out:
# BeginDate              0
# EndDate                0
# Type                   0
# PaperlessBilling       0
# PaymentMethod          0
# MonthlyCharges         0
# TotalCharges           0
# gender                 0
# SeniorCitizen          0
# Partner                0
# Dependents             0
# MultipleLines          0
# InternetService     1526
# OnlineSecurity      1526
# OnlineBackup        1526
# DeviceProtection    1526
# TechSupport         1526
# StreamingTV         1526
# StreamingMovies     1526
# dtype: int64

# %% [markdown]
# Получили 1526 пропусков, столько людей не пользуются интернетом, у данного оператора.
#
# Пропуски заменим значениями `No`

# %%
df = df.fillna('No')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BeginDate         7043 non-null   object
#  1   EndDate           7043 non-null   object
#  2   Type              7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   object
#  7   gender            7043 non-null   object
#  8   SeniorCitizen     7043 non-null   int64
#  9   Partner           7043 non-null   object
#  10  Dependents        7043 non-null   object
#  11  MultipleLines     7043 non-null   object
#  12  InternetService   7043 non-null   object
#  13  OnlineSecurity    7043 non-null   object
#  14  OnlineBackup      7043 non-null   object
#  15  DeviceProtection  7043 non-null   object
# ...

# %% [markdown]
# Данные объединили, займемся типами данных

# %%
df['BeginDate'] = pd.to_datetime(df['BeginDate'], format='%Y-%m-%d')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BeginDate         7043 non-null   datetime64[ns]
#  1   EndDate           7043 non-null   object
#  2   Type              7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   object
#  7   gender            7043 non-null   object
#  8   SeniorCitizen     7043 non-null   int64
#  9   Partner           7043 non-null   object
#  10  Dependents        7043 non-null   object
#  11  MultipleLines     7043 non-null   object
#  12  InternetService   7043 non-null   object
#  13  OnlineSecurity    7043 non-null   object
#  14  OnlineBackup      7043 non-null   object
#  15  DeviceProtection  7043 non-null   object
# ...

# %% [markdown]
# Прежде чем менять тип столбца `TotalCharges`, посмотрим какие данные он содержит

# %%
df['TotalCharges'].sort_values()
# Out:
# customerID
# 5709-LVOEQ
# 3213-VVOLG
# 2520-SGTTA
# 3115-CZMZD
# 2923-ARZLG
# 7644-OMVMY
# 2775-SEFEE
# 4075-WKNIU
# 1371-DWPAZ
# 4472-LVYGI
# 4367-NUYAO
# 6180-YBIQI      100.2
# 3178-FESZO     100.25
# 2587-YNLES     100.35
# 7802-EFKNY      100.4
# 7216-EWTRS      100.8
# 4719-UMSIY      100.9
# 8104-OSKWT     1001.2
# 7009-PCARS     1001.5
# 6705-LNMDD    1003.05
# 8219-VYBVI    1004.35
# 8859-YSTWS     1004.5
# 6907-CQGPN    1004.75
# 0621-CXBKL     1005.7
# 3472-QPRCH     1006.9
# 4163-HFTUK     1007.8
# 7872-BAAZR     1007.9
# 5138-WVKYJ    1008.55
# 5228-EXCET     1008.7
# 7427-AUFPY     1008.7
# 3016-KSVCP    1009.25
# 3594-KADLU      101.1
# 5419-JPRRN     101.45
# 8654-DHAOW     101.65
# 8746-OQQRW      101.9
# 4957-TIALW       1010
# 2195-VVRJF    1011.05
# 8706-HRADD     1011.5
# 0928-XUTSN     1011.8
# 9170-ARBTB     1012.4
# 9620-QJREV    1013.05
# 0608-JDVEC     1013.2
# 8107-KNCIM    1013.35
# 3378-AJRAO     1013.6
# 8148-NLEGT    1014.25
# 7634-HLQJR     1016.7
# ...

# %% [markdown]
# Видим пустые строки, посмотрим сколько таких строк

# %%
df.loc[df['TotalCharges'] == ' ']['TotalCharges'].count()
# Out:
# 11

# %%
df.loc[df['TotalCharges'] == ' ']
# Out:
#             BeginDate EndDate      Type PaperlessBilling  \
# customerID
# 4472-LVYGI 2020-02-01      No  Two year              Yes
# 3115-CZMZD 2020-02-01      No  Two year               No
# 5709-LVOEQ 2020-02-01      No  Two year               No
# 4367-NUYAO 2020-02-01      No  Two year               No
# 1371-DWPAZ 2020-02-01      No  Two year               No
# 7644-OMVMY 2020-02-01      No  Two year               No
# 3213-VVOLG 2020-02-01      No  Two year               No
# 2520-SGTTA 2020-02-01      No  Two year               No
# 2923-ARZLG 2020-02-01      No  One year              Yes
# 4075-WKNIU 2020-02-01      No  Two year               No
# 2775-SEFEE 2020-02-01      No  Two year              Yes
#
#                         PaymentMethod  MonthlyCharges TotalCharges  gender  \
# customerID
# 4472-LVYGI  Bank transfer (automatic)           52.55               Female
# 3115-CZMZD               Mailed check           20.25                 Male
# ...

# %% [markdown]
# Заметим что все 11 строк для пользователей пришедших 1 февраля 2020 года, это совпадает с датой нашей выгрузки. Наверное можно присвоить в этих строках TotalCharges =  MonthlyCharges. Но лучше уточнить, по данным пользователем со стажем побольше, например подулючившихся 01-01-2020

# %%
df[df['BeginDate'] == '01-01-2020']
# Out:
#             BeginDate EndDate            Type PaperlessBilling  \
# customerID
# 7590-VHVEG 2020-01-01      No  Month-to-month              Yes
# 7310-EGVHZ 2020-01-01      No  Month-to-month               No
# 3413-BMNZE 2020-01-01      No  Month-to-month               No
# 2273-QCKXA 2020-01-01      No  Month-to-month               No
# 2424-WVHPL 2020-01-01      No  Month-to-month               No
# 6380-ARCEH 2020-01-01      No  Month-to-month               No
# 3679-XASPY 2020-01-01      No  Month-to-month               No
# 3930-ZGWVE 2020-01-01      No  Month-to-month               No
# 6582-OIVSP 2020-01-01      No  Month-to-month               No
# 3645-DEYGF 2020-01-01      No  Month-to-month               No
# 4195-NZGTA 2020-01-01      No  Month-to-month               No
# 6469-MRVET 2020-01-01      No        One year              Yes
# 2080-SRCDE 2020-01-01      No  Month-to-month               No
# 8203-XJZRC 2020-01-01      No  Month-to-month               No
# ...

# %% [markdown]
# Судя по значениям в столбце TotalCharges равным MonthlyCharges у клиентов пришедших месяц назад и использующих различные варианты оплаты, получается что внось пришедшие в начале февраля клиенты еще не успели израсходовать вообще средств и поле TotalCharges стоит приравнять к нулю

# %%
df['TotalCharges'] = pd.to_numeric(df['TotalCharges'], errors='coerce')
df['TotalCharges'] = df['TotalCharges'].fillna(0)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BeginDate         7043 non-null   datetime64[ns]
#  1   EndDate           7043 non-null   object
#  2   Type              7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   float64
#  7   gender            7043 non-null   object
#  8   SeniorCitizen     7043 non-null   int64
#  9   Partner           7043 non-null   object
#  10  Dependents        7043 non-null   object
#  11  MultipleLines     7043 non-null   object
#  12  InternetService   7043 non-null   object
#  13  OnlineSecurity    7043 non-null   object
#  14  OnlineBackup      7043 non-null   object
#  15  DeviceProtection  7043 non-null   object
# ...

# %% [markdown]
# ### Анализ данных

# %% [markdown]
# Для начала посмотрим за какой период наши данные по приходу клиентов и количество этих новых клиентов по годам

# %%
pic=sns.displot(data = df['BeginDate'].dt.year, kde=True)
plt.title('Распределение клиентов по году подключения')
pic.set_xlabels('Год подключения клиента')
pic.set_ylabels('Количество');

# %% [markdown]
# Максимальное количество клиентов пришло в 2014 и 2019 году. Минимум в 2016 году. В 2019 году очень большой скачок, относительно 2018 года.

# %%
pic = sns.displot(pd.to_datetime(df[df['EndDate'] != 'No']['EndDate'], format='%Y-%m-%d %H:%M:%S').dt.year, kde=True)
plt.title('Распределение клиентов по году отключения')
pic.set_xlabels('Год отключения клиента')
pic.set_ylabels('Количество');

# %% [markdown]
# Больше всего клиентов ушло в 2019 году. В 2020 году несмотря на данные только за два месяца уже ушло достаточо много клиентов.
#
# До 2019 года ни ушел ни один клиент

# %% [markdown]
# Посмотрим через какой промежуток времени клиенты уходят от оператора

# %%
begin_date = df[df['EndDate'] != 'No']['BeginDate']
end_date = pd.to_datetime(df[df['EndDate'] != 'No']['EndDate'], format='%Y-%m-%d %H:%M:%S')
df_out_clients=pd.concat([begin_date,end_date],axis=1)
df_out_clients['days'] = df_out_clients['EndDate'] - df_out_clients['BeginDate']

# %%
df_out_clients.head(5)
# Out:
#             BeginDate    EndDate      days
# customerID
# 3668-QPYBK 2019-10-01 2019-12-01   61 days
# 9237-HQITU 2019-09-01 2019-11-01   61 days
# 9305-CDSKC 2019-03-01 2019-11-01  245 days
# 7892-POOKP 2017-07-01 2019-11-01  853 days
# 0280-XJGEX 2015-09-01 2019-10-01 1491 days

# %%
pic = sns.displot(df_out_clients['days'].dt.days, kde=True)
plt.title('Распределение клиентов по времени от подключения до ухода')
pic.set_xlabels('Количество дней')
pic.set_ylabels('Количество клиентов');

# %%
pic = sns.displot(df_out_clients[df_out_clients['days'] < '500 days']['days'].dt.days, kde=True)
plt.title('Распределение клиентов по времени от подключения до ухода')
pic.set_xlabels('Количество дней')
pic.set_ylabels('Количество клиентов');

# %% [markdown]
# Большая часть клиентов уходит очень быстро, в первые два месяца после подключения
#
# Посмотрим на распределение месячных плат за услуги связи

# %%
pic = sns.displot(df['MonthlyCharges'], kde=True)
plt.title('Распределение месячной платы')
pic.set_xlabels('Сумма помесячной платы')
pic.set_ylabels('Количество клиентов');

# %% [markdown]
# В распределении помесячной платы видно три вершины. Вероятно это пользователи с разными наборами услуг: телефон, интернет, интернет + телефон

# %%
pic = sns.displot(df['TotalCharges'], kde=True)
plt.title('Распределение общей платы')
pic.set_xlabels('Сумма общей платы')
pic.set_ylabels('Количество клиентов');

# %% [markdown]
# Распределение общей платы сильно смещено влево. Скорее всего многие не пользуюся доп услугами, и платят по минимуму либо так же связано с ранним уходом клиентов, в первые два месяца. Посмотрим на средние и медиану

# %%
print('Средняя общая плата', df['TotalCharges'].mean() )
print('Медиана общей платы', df['TotalCharges'].median() )
# Out:
# Средняя общая плата 2279.7343035638223
# Медиана общей платы 1394.55

# %% [markdown]
# Посмотрим на распределение бинарных признаков

# %%
col_name_binary = ['PaperlessBilling', 'gender', 'SeniorCitizen', 'Partner',\
       'Dependents', 'MultipleLines', 'OnlineSecurity', 'OnlineBackup', \
        'DeviceProtection', 'TechSupport', 'StreamingTV','StreamingMovies']

fig = plt.figure(figsize=(15,15))
for (i,j) in zip(col_name_binary,range(12)):
    fig.add_subplot(4, 3, j+1)
    plt.title('Распределение значений в столбце ' + i)
    plt.ylabel('Количество')
    plt.hist([df[df['EndDate'] != 'No'][i],df[df['EndDate'] == 'No'][i]],\
            label=['Ушли','Остались'])
    plt.legend(loc='best')
    plt.tight_layout()

# %% [markdown]
# Мужчин и женщин примерно поровну.
# Бумажными счетами пользуются чуть реже чем электронными
# Большой дисбаланс наблюдается у пожилых людей и зависимых материально, тут логично - пожилые реже пользуются интернетом.
#
# Самыми популярными услугами являются стриминг ТВ и Фильмов, мультилинии в телефонии.
#
# Так же видна разница между клиентами которые ушли от оператора и теми которые остались, отключившиеся абонентами в целом реже пользовались доп. услугами
#
#
# Теперь построим графики для отсавшихся полей

# %%
col_name_category = ['Type', 'PaymentMethod', 'InternetService']

for (i,j) in zip(col_name_category,range(3)):
    fig = plt.figure(figsize=(20,7))
    plt.title('Распределение значений в столбце ' + i)
    plt.ylabel('Количество')
    plt.hist([df[df['EndDate'] != 'No'][i],df[df['EndDate'] == 'No'][i]],\
            label=['Ушли','Остались'])
    plt.legend(loc='best');
    plt.tight_layout()
    plt.show();

# %% [markdown]
# Большая часть клиентов на помесячной оплате, на втором месте те кто готов платить на два года вперед
#
# По способам платежей небольшое приемущество у электронных чеков, но большого дисбаланса нет
# ПО типу подключения либирует оптика, и конечно есть часть клиентов которые вообще не пользуются интернетом, тут они появилимь из-за объединения таблиц
#
# Больше всего ушло клиентов с помесячной оплатой, логично их не держит внесенная предоплата на год или два года вперед.
#
# По типу оплаты особых различи не видно, электронные чеки так же лидируют у отключившихся абонентов, зато у оставшихся теперь практически паритет между всеми способами оплаты услуг связи.
#
# Отключались чаще всего пользователи с оптиковолоконным подключением к сети интернет, а вот к телефонной связи и DSL подключению видимо меньше вопросов возникало. На эту же мысль наталкивает, что среди оставшихся клиентов большинство, хоть и не с большим перевесом, пользуется именно DSL интернетом

# %% [markdown]
# ## Подготовка данных для модели машинного обучения
#
# ### Добавим target

# %%
df['quit'] = pd.Series(np.where(df['EndDate'].values == 'No', 0, 1),df.index)

# %%
df.head()
# Out:
#             BeginDate              EndDate            Type PaperlessBilling  \
# customerID
# 7590-VHVEG 2020-01-01                   No  Month-to-month              Yes
# 5575-GNVDE 2017-04-01                   No        One year               No
# 3668-QPYBK 2019-10-01  2019-12-01 00:00:00  Month-to-month              Yes
# 7795-CFOCW 2016-05-01                   No        One year               No
# 9237-HQITU 2019-09-01  2019-11-01 00:00:00  Month-to-month              Yes
#
#                         PaymentMethod  MonthlyCharges  TotalCharges  gender  \
# customerID
# 7590-VHVEG           Electronic check           29.85         29.85  Female
# 5575-GNVDE               Mailed check           56.95       1889.50    Male
# 3668-QPYBK               Mailed check           53.85        108.15    Male
# 7795-CFOCW  Bank transfer (automatic)           42.30       1840.75    Male
# 9237-HQITU           Electronic check           70.70        151.65  Female
#
# ...

# %%
df['quit'].value_counts() / df['quit'].shape
# Out:
# 0    0.73463
# 1    0.26537
# Name: quit, dtype: float64

# %% [markdown]
# Есть небольшой дисбаланс классов которые наша модель должна предсказывать

# %% [markdown]
# ### Добавим признак "время жизни" клиента

# %% [markdown]
# Поскольку мы знаем дату нашей выгрузки 01-02-2020, можем для всех клиентов посчитать сколько они уже пользуются услугами компании

# %%
final_date =  pd.to_datetime('2020-02-01', format='%Y-%m-%d')
final_date
# Out:
# Timestamp('2020-02-01 00:00:00')

# %%
df.loc[df['EndDate'] == 'No', 'EndDate'] = final_date
df['life_time'] = (pd.to_datetime(df['EndDate']) - df['BeginDate']).dt.days

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   BeginDate         7043 non-null   datetime64[ns]
#  1   EndDate           7043 non-null   object
#  2   Type              7043 non-null   object
#  3   PaperlessBilling  7043 non-null   object
#  4   PaymentMethod     7043 non-null   object
#  5   MonthlyCharges    7043 non-null   float64
#  6   TotalCharges      7043 non-null   float64
#  7   gender            7043 non-null   object
#  8   SeniorCitizen     7043 non-null   int64
#  9   Partner           7043 non-null   object
#  10  Dependents        7043 non-null   object
#  11  MultipleLines     7043 non-null   object
#  12  InternetService   7043 non-null   object
#  13  OnlineSecurity    7043 non-null   object
#  14  OnlineBackup      7043 non-null   object
#  15  DeviceProtection  7043 non-null   object
# ...

# %% [markdown]
# ### Обработаем бинарные и категориальные признаки
# Воспользуемся методом One-Hot_Encoder

# %%
df = pd.get_dummies(df, columns = ['Type', 'InternetService','PaymentMethod','PaperlessBilling',\
                                   'gender', 'SeniorCitizen', 'Partner','Dependents', 'MultipleLines', \
                                   'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',\
                                   'StreamingTV','StreamingMovies'], drop_first = True)

# %%
first_look(df)
# Out:
#             BeginDate              EndDate  MonthlyCharges  TotalCharges  \
# customerID
# 7590-VHVEG 2020-01-01  2020-02-01 00:00:00           29.85         29.85
# 5575-GNVDE 2017-04-01  2020-02-01 00:00:00           56.95       1889.50
# 3668-QPYBK 2019-10-01  2019-12-01 00:00:00           53.85        108.15
# 7795-CFOCW 2016-05-01  2020-02-01 00:00:00           42.30       1840.75
# 9237-HQITU 2019-09-01  2019-11-01 00:00:00           70.70        151.65
#
#             quit  life_time  Type_One year  Type_Two year  \
# customerID
# 7590-VHVEG     0         31              0              0
# 5575-GNVDE     0       1036              1              0
# 3668-QPYBK     1         61              0              0
# 7795-CFOCW     0       1371              1              0
# 9237-HQITU     1         61              0              0
#
#             InternetService_Fiber optic  InternetService_No  \
# customerID
# 7590-VHVEG                            0                   0
# ...

# %% [markdown]
# ### Удалим лишние признаки для избежания утечки и проверим корреляцию

# %%
df = df.drop(['EndDate','BeginDate'], axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 23 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   MonthlyCharges                         7043 non-null   float64
#  1   TotalCharges                           7043 non-null   float64
#  2   quit                                   7043 non-null   int64
#  3   life_time                              7043 non-null   int64
#  4   Type_One year                          7043 non-null   uint8
#  5   Type_Two year                          7043 non-null   uint8
#  6   InternetService_Fiber optic            7043 non-null   uint8
#  7   InternetService_No                     7043 non-null   uint8
#  8   PaymentMethod_Credit card (automatic)  7043 non-null   uint8
#  9   PaymentMethod_Electronic check         7043 non-null   uint8
# ...

# %%
m = np.tri(len(df.columns),len(df.columns)).transpose()
heatmap = plt.figure(figsize=(16, 16))
matrix = df.phik_matrix(interval_cols=df.columns)
heatmap = sns.heatmap(matrix, annot=True, fmt='.1g', mask=m)
heatmap.set_title('Матрица корреляции $\phi_K$', fontdict={'fontsize':14}, pad=12);

# %% [markdown]
# С предсказываемым нами фактом ухода абонента заметных корреляций ведущих к утечке нет.
#
# В целом между признаками есть заметные зависимости только у следующих пар признаков:
# * Месячный платеж - Факт отсутсвия интернета, факт оптиковолоконного подключения, наличие доп услуг интернета и телефона
# * Время жизни - общая сумма платежей и факт ухода клиента
#
# У таргета нулевой коэффициент корреляции от пола абонента и очень низкая от наличий мультилиний в телефоне. Думаю эти признаки можно сразу удалить
#
# Так же удалим признак `MonthlyCharges`, у него сильная корреляция с несколькими признаками сразу

# %% [markdown]
# ### Выделение тестовой выборки

# %%
target = df['quit']
features = df.drop(['quit','gender_Male','MultipleLines_Yes','MonthlyCharges'], axis=1)

# %%
target_train, target_test, features_train, features_test = \
train_test_split(target, features, test_size = 0.25, random_state = 120922, stratify=target)

# %%
features_train.shape, features_test.shape
# Out:
# ((5282, 19), (1761, 19))

# %% [markdown]
# ## Обучение моделей

# %% [markdown]
# ### Логистическая регрессия
#
# Начнем с линейной модели

# %%
# %%time
c_values = [0.01, 0.1, 0.2, 0.5, 1, 5, 10 , 100]
logit_searcher = LogisticRegressionCV(Cs=c_values, cv=5,scoring='roc_auc',\
                                      random_state=120922, class_weight='balanced')
logit_searcher.fit(features_train, target_train);
# Out:
# CPU times: user 1.27 s, sys: 134 ms, total: 1.4 s
# Wall time: 1.42 s
# LogisticRegressionCV(Cs=[0.01, 0.1, 0.2, 0.5, 1, 5, 10, 100],
#                      class_weight='balanced', cv=5, random_state=120922,
#                      scoring='roc_auc')

# %%
logit_searcher.scores_
# Out:
# {1: array([[0.82252265, 0.82344902, 0.82345361, 0.82344902, 0.82345361,
#          0.82344902, 0.82345361, 0.82344902],
#         [0.83748211, 0.84473255, 0.84473255, 0.84473255, 0.84473255,
#          0.84473255, 0.84473255, 0.84473255],
#         [0.83237988, 0.83810061, 0.8380914 , 0.83810061, 0.8380914 ,
#          0.83810061, 0.8380914 , 0.83810061],
#         [0.85456094, 0.85980762, 0.85990427, 0.86045195, 0.86045195,
#          0.86045195, 0.86044735, 0.86045195],
#         [0.846875  , 0.84777246, 0.84777246, 0.84777246, 0.84777246,
#          0.84777246, 0.84777246, 0.84777246]])}

# %%
roc_auc_score(target_train,logit_searcher.predict_proba(features_train)[:,1])
# Out:
# 0.8459577260761505

# %% [markdown]
# Метрика линейной модели получилась достаточно низкой, попробуем случайный лес

# %% [markdown]
# ### Случайный лес

# %%
forest_model = RandomForestClassifier(random_state=120922, n_estimators=100, class_weight = 'balanced')

# %%
param_grid_forest = [{'max_depth': range (5,14,1), 'max_features': range(2,20,2)}]

# %%
grid_search_forest = GridSearchCV(forest_model, param_grid_forest, cv=5, scoring='roc_auc', refit=True)

# %%
# %%time
grid_search_forest.fit(features_train, target_train)
# Out:
# CPU times: user 3min 19s, sys: 2.16 s, total: 3min 21s
# Wall time: 3min 25s
# GridSearchCV(cv=5,
#              estimator=RandomForestClassifier(class_weight='balanced',
#                                               random_state=120922),
#              param_grid=[{'max_depth': range(5, 14),
#                           'max_features': range(2, 20, 2)}],
#              scoring='roc_auc')

# %%
grid_search_forest.best_score_
# Out:
# 0.8707961568849942

# %%
grid_search_forest.best_params_
# Out:
# {'max_depth': 10, 'max_features': 18}

# %% [markdown]
# Случайный лес показывает метрику лучше линейной модели

# %%
forest_model = grid_search_forest.best_estimator_

# %% [markdown]
# ### Градиентный бустинг LightGBM

# %%
lgbm_model = LGBMClassifier(random_state=120922, class_weight='balanced', objective = 'binary')

# %%
param_grid_bosting = [{'max_depth': range (1,4,1), 'n_estimators': range(100,1100,100), 'learning_rate': (0.1,0.3,0.5,1)}]

# %%
grid_search_bosting = GridSearchCV(lgbm_model, param_grid_bosting, cv=5, scoring='roc_auc', refit=True)

# %%
# %%time
grid_search_bosting.fit(features_train, target_train)
# Out:
# CPU times: user 4min 43s, sys: 1.72 s, total: 4min 44s
# Wall time: 1min 12s
# GridSearchCV(cv=5,
#              estimator=LGBMClassifier(class_weight='balanced',
#                                       objective='binary', random_state=120922),
#              param_grid=[{'learning_rate': (0.1, 0.3, 0.5, 1),
#                           'max_depth': range(1, 4),
#                           'n_estimators': range(100, 1100, 100)}],
#              scoring='roc_auc')

# %%
grid_search_bosting.best_score_
# Out:
# 0.9216963696088556

# %%
grid_search_bosting.best_params_
# Out:
# {'learning_rate': 0.5, 'max_depth': 2, 'n_estimators': 400}

# %%
lgbm_model  = grid_search_bosting.best_estimator_

# %% [markdown]
# Посмотрим какие из признаков дают наибольший вклад

# %%
importance = lgbm_model.feature_importances_
name_features = features_train.columns
imp_features = pd.DataFrame(importance,columns=['Imp'],index=name_features)

# %%
imp_features.sort_values(by='Imp', ascending=False)
# Out:
#                                        Imp
# life_time                              642
# TotalCharges                           363
# Type_One year                           20
# PaperlessBilling_Yes                    18
# Type_Two year                           16
# PaymentMethod_Mailed check              15
# OnlineSecurity_Yes                      15
# SeniorCitizen_1                         14
# Dependents_Yes                          12
# TechSupport_Yes                         12
# StreamingTV_Yes                         12
# InternetService_Fiber optic             10
# InternetService_No                      10
# StreamingMovies_Yes                      9
# Partner_Yes                              8
# DeviceProtection_Yes                     8
# PaymentMethod_Electronic check           7
# OnlineBackup_Yes                         5
# PaymentMethod_Credit card (automatic)    4

# %% [markdown]
# Видно что часть признаков имеют очень низкую значимость, удалим их. Это следующие признаки:
# * `StreamingMovies_Yes`
# * `Partner_Yes`
# * `DeviceProtection_Yes`
# * `PaymentMethod_Electronic check`
# * `OnlineBackup_Yes`
# * `PaymentMethod_Credit card (automatic)`

# %%
lgbm_features_train = features_train.drop(['Partner_Yes','DeviceProtection_Yes','StreamingMovies_Yes',\
                                           'PaymentMethod_Credit card (automatic)',\
                                           'PaymentMethod_Electronic check', 'Dependents_Yes'], axis=1)
lgbm_features_test = features_test.drop(['Partner_Yes','DeviceProtection_Yes','StreamingMovies_Yes',\
                                           'PaymentMethod_Credit card (automatic)',\
                                           'PaymentMethod_Electronic check', 'Dependents_Yes'], axis=1)

# %%
# %%time
grid_search_bosting.fit(lgbm_features_train, target_train)
# Out:
# CPU times: user 4min 24s, sys: 1.69 s, total: 4min 25s
# Wall time: 1min 8s
# GridSearchCV(cv=5,
#              estimator=LGBMClassifier(class_weight='balanced',
#                                       objective='binary', random_state=120922),
#              param_grid=[{'learning_rate': (0.1, 0.3, 0.5, 1),
#                           'max_depth': range(1, 4),
#                           'n_estimators': range(100, 1100, 100)}],
#              scoring='roc_auc')

# %%
grid_search_bosting.best_score_
# Out:
# 0.9241924191164523

# %% [markdown]
# С усеченным набором признаков модель показала результаты немного выше, оставим ее

# %%
lgbm_model = grid_search_bosting.best_estimator_

# %% [markdown]
# ###  Градиентный бустинг CatBoost

# %%
cat_model = CatBoostClassifier(loss_function='CrossEntropy', random_state=120922)

# %%
param_grid_cat = {
    'iterations': [1000,2000,3000],
    'learning_rate' : [0.3,0.1,0.05],
    'depth' : range(1,6,2),
    'verbose' : [False]
}

# %%
grid_search_cat = GridSearchCV(cat_model, param_grid_cat, cv = 5, scoring = 'roc_auc')

# %%
# %%time
grid_search_cat.fit(features_train,target_train)
# Out:
# CPU times: user 12min 47s, sys: 48.6 s, total: 13min 36s
# Wall time: 5min 5s
# GridSearchCV(cv=5,
#              estimator=<catboost.core.CatBoostClassifier object at 0x12798f160>,
#              param_grid={'depth': range(1, 6, 2),
#                          'iterations': [1000, 2000, 3000],
#                          'learning_rate': [0.3, 0.1, 0.05],
#                          'verbose': [False]},
#              scoring='roc_auc')

# %%
grid_search_cat.best_score_
# Out:
# 0.9285830114413599

# %%
grid_search_cat.best_params_
# Out:
# {'depth': 3, 'iterations': 2000, 'learning_rate': 0.1, 'verbose': False}

# %%
cat_model = grid_search_cat.best_estimator_

# %%
importance = cat_model.feature_importances_
name_features = cat_model.feature_names_
imp_features = pd.DataFrame(importance,columns=['Imp'],index=name_features)
imp_features.sort_values(by='Imp', ascending=False)
# Out:
#                                              Imp
# life_time                              64.727252
# TotalCharges                           12.688433
# Type_Two year                           4.955739
# InternetService_Fiber optic             3.364456
# InternetService_No                      2.348041
# Type_One year                           1.900806
# PaymentMethod_Electronic check          1.193691
# StreamingTV_Yes                         1.185132
# PaperlessBilling_Yes                    1.069540
# SeniorCitizen_1                         0.910331
# StreamingMovies_Yes                     0.848464
# TechSupport_Yes                         0.794782
# PaymentMethod_Mailed check              0.784111
# OnlineSecurity_Yes                      0.774146
# OnlineBackup_Yes                        0.576198
# Dependents_Yes                          0.551420
# Partner_Yes                             0.548001
# DeviceProtection_Yes                    0.434643
# ...

# %% [markdown]
# Отберем признаки с уровнем значимости выше 1, удалим признаки:
# * `SeniorCitizen_1`
# * `StreamingMovies_Yes`
# * `TechSupport_Yes`
# * `PaymentMethod_Mailed check`
# * `OnlineSecurity_Yes`
# * `OnlineBackup_Yes`
# * `Dependents_Yes`
# * `Partner_Yes`
# * `DeviceProtection_Yes`
# * `PaymentMethod_Credit card (automatic)`

# %%
catboost_features_train = features_train.drop(['SeniorCitizen_1','StreamingMovies_Yes','TechSupport_Yes',\
                          'PaymentMethod_Mailed check','OnlineSecurity_Yes','OnlineBackup_Yes',\
                         'Dependents_Yes','Partner_Yes','DeviceProtection_Yes',\
                        'PaymentMethod_Credit card (automatic)'], axis=1)
catboost_features_test = features_test.drop(['SeniorCitizen_1','StreamingMovies_Yes','TechSupport_Yes',\
                          'PaymentMethod_Mailed check','OnlineSecurity_Yes','OnlineBackup_Yes',\
                         'Dependents_Yes','Partner_Yes','DeviceProtection_Yes',\
                        'PaymentMethod_Credit card (automatic)'], axis=1)
cat_model_features = CatBoostClassifier(loss_function='CrossEntropy', random_state=120922, verbose=False)
grid_search_cat_features = GridSearchCV(cat_model_features, param_grid_cat, cv = 5, scoring = 'roc_auc')

# %%
# %%time
grid_search_cat_features.fit(catboost_features_train,target_train);
# Out:
# CPU times: user 11min 41s, sys: 50.7 s, total: 12min 32s
# Wall time: 4min 40s
# GridSearchCV(cv=5,
#              estimator=<catboost.core.CatBoostClassifier object at 0x1279531c0>,
#              param_grid={'depth': range(1, 6, 2),
#                          'iterations': [1000, 2000, 3000],
#                          'learning_rate': [0.3, 0.1, 0.05],
#                          'verbose': [False]},
#              scoring='roc_auc')

# %%
grid_search_cat_features.best_score_
# Out:
# 0.9348681793405627

# %%
grid_search_cat_features.best_params_
# Out:
# {'depth': 3, 'iterations': 2000, 'learning_rate': 0.1, 'verbose': False}

# %%
cat_model_features = grid_search_cat_features.best_estimator_

# %% [markdown]
# Модель с усеченным набором признаков показала результаты лучше.
#
#
# В итоге на тестовой выборке лучшую метрику ROC_AUC показала модель на основе градиентного бустинга реализованная в библиотеке CatBoost с усеченным набором признаков

# %% [markdown]
# ## Проверка модели на тестовой выборке

# %% [markdown]
# Лучшей моделью оказалась модель на основе градиентного бустинка реализованного в библиотеке CatBoost, посмотрим на значение метрики на тестовой выборке

# %%
print('ROC_AUC лучшей модели на тестовой выборке',\
      round(roc_auc_score(target_test,cat_model_features.predict_proba(catboost_features_test)[:,1]), 3))
# Out:
# ROC_AUC лучшей модели на тестовой выборке 0.939

# %%
print('Accuracy лучшей модели на тестовой выборке',\
      round(accuracy_score(target_test,cat_model_features.predict(catboost_features_test)),3))
# Out:
# Accuracy лучшей модели на тестовой выборке 0.898

# %% [markdown]
# Сравним точность со случайной моделью

# %%
lst = [randint(0, 1) for i in range(len(target_test))] # список со случайно сгенерированными 0 и 1
result_adeq = accuracy_score(target_test,lst)  # считаем параметр accuracy 
print('Точность случайного списка', round(result_adeq,4))
lst_zero = [0 for i in range(len(target_test))]
lst_one = [1 for i in range(len(target_test))]
result_adeq = accuracy_score(target_test,lst_zero)
print('Точность случайного списка из нулей', round(result_adeq,4))
result_adeq = accuracy_score(target_test,lst_one)
print('Точность случайного списка из единиц', round(result_adeq,4))
# Out:
# Точность случайного списка 0.4957
# Точность случайного списка из нулей 0.7348
# Точность случайного списка из единиц 0.2652

# %% [markdown]
# Итоговые значения метрик на тестовой выборке соответствуют критерию ROC_AUC выше 0.85. Случайная модель будет давать ROC_AUC = 0.5. Точность нашей модели выше константной и случайно, поэтому ее можно считать адекватной.

# %% [markdown]
# ## Интерпретация модели

# %%
importance = cat_model_features.feature_importances_
name_features = cat_model_features.feature_names_
imp_features = pd.DataFrame(importance,columns=['Imp'],index=name_features)
imp_features = imp_features.sort_values(by='Imp', ascending=True)
imp_features.plot(y='Imp', kind='barh', grid=True, figsize=(10,7))
plt.title('Значимость признаков для модели градиентного бустинга')
plt.xlabel('Уровень значимости')
plt.ylabel('Названия признаков')
plt.show();

# %%
#cat_model_features.calc_feature_statistics(catboost_features_test,target_test, plot=True)

# %% [markdown]
# Самым значимым признаком с большим отрывом является время, в днях, сколько клиент пользуется(пользовался) услугами компании, на втором месте общая сумма платежей и на последней ступени пьедестала факт двухгодичного контракта.

# %% [markdown]
# ## Вывод

# %% [markdown]
# **В процессе работы были выполнены следующие основные шаги:**
#
# 1. Импорт неоходимых библиотек;
# 2. Чтение и первое знакомство с данными;
# 3. Для удобства дальнейшей работы все 4 датафрэйма были объединены в один, появившиеся при этом пропуски, а это отсутсвие информации по услугам интернета или телефонии у клиентов которые этими услугами не пользуются, были заполнены значениями `No`;
# 4. Далее была проведена работа по приведению типов данных к соответсвию их содержанию и заполнены образовавшиеся после этого пропуски в столбце `TotalChanges` нулями, поскольку было замечено что все пропуски принадлежат новый клиентам, которые еще не успели ничего израсходовать из своих тарифов.
#
# **Следующим этапом работы был исследователський анализ имеющихся данных.**
#
# Максимальный приток клиентов был хафиксирован в 2014 и 2019 годах, отток клиентов начался только с 2019 года и в 2020 году по данным за первый месяц видно, что отток будет не меньше чем в 2019 году если ни чего не предпринимать.
#
# Построены графики распределения имеющихся данных, выявлено что из тех клиентоа кто ушел от оператора большая часть пользовались услугами два и менее месяца.
#
# У месячной оплаты видны три вершины, вероятно это клиенты с наборами услуг: телефон, интернет и интеренет + телефон.
#
# Для категориальных переменных построили гистограммы с разбиением по типу клиента: ушел или остался
#
# **Далее перешли к подготовке данных для модели машинного обучения**
#
# Поскольку перед нами стояла задача предсказать факт ухода клиента а не дату его ухода, был создан предсказываемый ключевой признак - факт ухода из стобца `EndDate`. Для клиентов у кого в этом столбце стояла дата ухода, таргету присвоили значение 1, для клиентов со значением `No` - 0. Посмотрели на баланс предсказываемых классов, в нашем наборе данных этот баланс составил примерно 3 к 1, 26.5 % клиентов компании ушли.
#
# Мы знаем дату выгрузки данных - 01-02-2020, значит для всех клиентов мы можем посчитать сколько времени тот или иной клиент пользуется (пользовался, для ушедших) нашими услугами. Данный признак выраженный в количестве дней добавили в исходный набор данных для каждого клиента. Назовем этот признак "время жизни".
#
# Следующим шагом провели кодирование всех категориальныйх признаков в нашем наборе данных методом One-Hot-Encoding, с отбрасываем для каждого признака первого столбца.
#
# Два признакак с датами начала договора и конца договора явно могут привести к утечке в комбинации с признаком "время жизни", удалим оба этих столбца.
#
# Теперь все наши признаки выражаются числами, можно посмотреть на связь между признаками, построили матрицу $\phi_K$ корреляции между нашими признаками. Выявивили зависимости между признаками и слабо влияющие на таргет признаки, в итоге пришли к выводу о необходимости удаления следующих признаков:
# * `gender_Male`
# * `MultipleLines_Yes`
# * `MonthlyCharges`
#
# И завершающий этап в подготовке данных для обучения моделей - разбиение имеющейся выборки на столбце с результатами предсказаний target, и матрицу со значениями признаков features. И разбиение этих данных на обучающую и тестовую выборкии в соотношении 3:1 с сохранением распределения предсказываемых классов.
#
# **Обучение моделей машинного обучения и подбор гиперпараметров**
#
# Нас интересовало значение метрики ROC_AUC.
#
# Начали с модели логистической регресси, с подбором гиперпараметра `C` методом `LogisticRegressionCV`, получили значение ROC_AUC 0.846 на кросс-валидации.
#
# Следующей моделью попробовали случайны лес после подбора гиперпараметров получили значение метрики 0.871 на кросс-валидации, со следующими гиперпараметрами `max_depth` *10*, `max_features` *18*.
#
# После этого перешли к моделям на основе градиентного бустинга реализованных в библиотеках LigthGBM и CatBoost, и тут первое отступление от плана - изначально планировал пользоваться только бибилиотекой LigthGBM, но решил еще попробовать CatBoost - она дала лучшие значения метрики ROC_AUC
#
# После подбора гиперпараметров методом `GridSearchCV` модель `LGBMClassifier` показала результат 0.9216 на кросс-валидации, со следующими гиперпараметрами `learning_rate` *0.5* , `max_depth` *2* , `n_estimators` *400*. Посмотрели на значимость признаков для модели имеющимся методом `feature_importances_`, и отбросили признаки со значимость менее 10:
# * `StreamingMovies_Yes`
# * `Partner_Yes`
# * `DeviceProtection_Yes`
# * `PaymentMethod_Electronic check`
# * `OnlineBackup_Yes`
# * `PaymentMethod_Credit card (automatic)`
#
# Запустили подбор гиперпараметров для аналогичной модели заного, по усеченому набору признаков, получили значение метрики ROC_AUC 0.924
#
# Далее перешли к модели `CatBoostClassifier`.
# Начали с полного набора признаком и после подбора гиперпараметров методом `GridSearchCV` модель  показала результат 0.9285 на кросс-валидации, со следующими гиперпараметрами `learning_rate` *0.1* , `depth` *3* , `iterations` *2000*. Посмотрели на значимость признаков для модели имеющимся методом `feature_importances_`, и отбросили признаки со значимость менее 1:
# * `SeniorCitizen_1`
# * `StreamingMovies_Yes`
# * `TechSupport_Yes`
# * `PaymentMethod_Mailed check`
# * `OnlineSecurity_Yes`
# * `OnlineBackup_Yes`
# * `Dependents_Yes`
# * `Partner_Yes`
# * `DeviceProtection_Yes`
# * `PaymentMethod_Credit card (automatic)`
#
# Запустили для модели с усеченным набором признаков подбор гиперпараметров и получили значение метрики 0.9348 при тех же гиперпараметрах `learning_rate` *0.1* , `depth` *3* , `iterations` *2000*
#
#
# В итоге лучшей моделью на кросс-валидации оказалась модель `CatBoostClassifier` с гиперпараметрами `learning_rate` *0.1* , `depth` *3* , `iterations` *2000* и работающая на усеченном наборе признаков:
# * `life_time`
# * `TotalCharges`
# * `Type_Two year`
# * `InternetService_Fiber optic`
# * `InternetService_No`
# * `Type_One year`
# * `PaymentMethod_Electronic check`
# * `StreamingTV_Yes`
# * `PaperlessBilling_Yes`
#
# **Проверка модели на тестовой выборке**
#
# На тестовой выборке наша лучшая модель показала значение метрики ROC_ACU 0.939, и Accuracy score 0.898.
# Был так же проведен анализ значимости признаков для итоговой модели. Наиболее важными признаками оказались:
# 1. "Время жизни" `life_time`
# 2. Общий размер платы за услуги `TotalChanges`
# 3. Факт наличия контракта на два года `Type_Two year`
#
# ___
#
# **Ключевые шаги для успешного выполнения хадания**
#
# 1. Провести верную предобработку данных, привести типы.
# 2. Добавить новые признаки, "время жизни" и факт ухода. Удалить после этого оба признака с датами.
# 3. Использовать OHE для категориальных переменных
# 4. Использовать модель на основе градиентного бустинга с подбором гиперпараметров
#
#
#
#
# ---
#
# **Во время выполнения задачи пришлось столкнуться со следующими сложностями:**
#
# 1. Опечатка при создании нового признака отняла много времени на попытки добиться высоких значений метрики при подборе различных гиперпараметров модели.
# 2. Изначально были рассмотрены не верные коэффициенты корреляции Пирсона для оценки связи между признаками.

# %% [markdown]
# ## Вопросы:
#
# * Есть 11 строк с пустой строкой в поле TotalCharges. Заметим что все 11 строк для пользователей пришедших 1 февраля 2020 года, это совпадает с датой нашей выгрузки. Наверное можно присвоить в этих строках TotalCharges = MonthlyCharges. Но лучше уточнить
# * Что-то поменялось в тарифах в 2019 году из-за чего может быть такой всплеск ухода клиентов?
# * Можем ли мы снизить количество признаков для модели если часть из них окажуться между собой коллинеарны? (зависимы)
